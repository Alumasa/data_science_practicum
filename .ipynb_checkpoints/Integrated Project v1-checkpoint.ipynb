# %%
import warnings
warnings.filterwarnings("ignore")

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('datasets/games.csv')

# %%
df.head()
# Out:
#                        Name Platform  Year_of_Release         Genre  NA_sales  \
# 0                Wii Sports      Wii           2006.0        Sports     41.36
# 1         Super Mario Bros.      NES           1985.0      Platform     29.08
# 2            Mario Kart Wii      Wii           2008.0        Racing     15.68
# 3         Wii Sports Resort      Wii           2009.0        Sports     15.61
# 4  Pokemon Red/Pokemon Blue       GB           1996.0  Role-Playing     11.27
#
#    EU_sales  JP_sales  Other_sales  Critic_Score User_Score Rating
# 0     28.96      3.77         8.45          76.0          8      E
# 1      3.58      6.81         0.77           NaN        NaN    NaN
# 2     12.76      3.79         3.29          82.0        8.3      E
# 3     10.93      3.28         2.95          80.0          8      E
# 4      8.89     10.22         1.00           NaN        NaN    NaN

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 16715 entries, 0 to 16714
# Data columns (total 11 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Name             16713 non-null  object
#  1   Platform         16715 non-null  object
#  2   Year_of_Release  16446 non-null  float64
#  3   Genre            16713 non-null  object
#  4   NA_sales         16715 non-null  float64
#  5   EU_sales         16715 non-null  float64
#  6   JP_sales         16715 non-null  float64
#  7   Other_sales      16715 non-null  float64
#  8   Critic_Score     8137 non-null   float64
#  9   User_Score       10014 non-null  object
#  10  Rating           9949 non-null   object
# dtypes: float64(6), object(5)
# memory usage: 1.4+ MB

# %%
df.sample(10)
# Out:
#                                 name platform year_of_release         genre  \
# 12245              Gundam Try Age SP      3DS      2014-01-01      Strategy
# 7696                     UFC: Tapout       XB      2002-01-01      Fighting
# 4545         Naruto: Ninja Council 3       DS      2006-01-01        Action
# 6041   Sakura Wars 4: Koi Seyo,Otome       DC      2002-01-01     Adventure
# 7418   Prince of Persia: Revelations      PSP      2005-01-01     Adventure
# 1475     The Elder Scrolls V: Skyrim      PS4      2016-01-01  Role-Playing
# 12105              Heavenly Guardian      Wii      2007-01-01       Shooter
# 8054                 Mega Man Soccer     SNES      1993-01-01        Sports
# 2915             Chocobo's Dungeon 2       PS      1998-01-01  Role-Playing
# 12722    Samurai Warriors 4: Empires      PS3      2015-01-01        Action
#
#        na_sales  eu_sales  jp_sales  other_sales  critic_score  user_score  \
# 12245      0.00      0.00      0.07         0.00           NaN         NaN
# 7696       0.14      0.05      0.00         0.01           NaN         NaN
# 4545       0.39      0.00      0.00         0.03          56.0         6.5
# 6041       0.00      0.00      0.29         0.00           NaN         NaN
# 7418       0.18      0.01      0.00         0.02           NaN         NaN
# 1475       0.48      0.59      0.04         0.21           NaN         NaN
# 12105      0.06      0.00      0.00         0.00           NaN         5.0
# 8054       0.04      0.01      0.13         0.00           NaN         NaN
# 2915       0.04      0.03      0.58         0.05           NaN         NaN
# 12722      0.00      0.00      0.06         0.00           NaN         5.0
#
#       rating
# 12245    NaN
# 7696     NaN
# 4545    E10+
# 6041     NaN
# 7418     NaN
# 1475     NaN
# 12105      E
# 8054     NaN
# 2915     NaN
# 12722      T

# %% [markdown]
# ### Data Preprocessing

# %% [markdown]
# Make columns lowercase.
#
# I will use the lower() method on the strings of columns

# %%
df.columns = df.columns.str.lower()
df.columns
# Out:
# Index(['name', 'platform', 'year_of_release', 'genre', 'na_sales', 'eu_sales',
#        'jp_sales', 'other_sales', 'critic_score', 'user_score', 'rating'],
#       dtype='object')

# %% [markdown]
# Convert data types:

# %% [markdown]
# I will convert the `year_of_release` to datetime, to allow for time analysis in the years.

# %%
df.year_of_release.dtype
# Out:
# dtype('float64')

# %%
df.year_of_release = pd.to_datetime(df.year_of_release, format='%Y')

# %% [markdown]
# I will change the `user_score` to float, because it has ratings of float data types.

# %%
df.user_score.dtype
# Out:
# dtype('O')

# %%
df.user_score.value_counts()
# Out:
# tbd    2424
# 7.8     324
# 8       290
# 8.2     282
# 8.3     254
#        ...
# 0.9       2
# 1.3       2
# 2.3       2
# 0         1
# 9.7       1
# Name: user_score, Length: 96, dtype: int64

# %%
df.query('user_score == "tbd"').head()
# Out:
#                                          name platform year_of_release  \
# 119                             Zumba Fitness      Wii      2010-01-01
# 301            Namco Museum: 50th Anniversary      PS2      2005-01-01
# 520                           Zumba Fitness 2      Wii      2011-01-01
# 645                              uDraw Studio      Wii      2010-01-01
# 657  Frogger's Adventures: Temple of the Frog      GBA             NaT
#
#          genre  na_sales  eu_sales  jp_sales  other_sales  critic_score  \
# 119     Sports      3.45      2.59       0.0         0.66           NaN
# 301       Misc      2.08      1.35       0.0         0.54          61.0
# 520     Sports      1.51      1.03       0.0         0.27           NaN
# 645       Misc      1.65      0.57       0.0         0.20          71.0
# 657  Adventure      2.15      0.18       0.0         0.07          73.0
#
#     user_score rating
# 119        tbd      E
# 301        tbd   E10+
# 520        tbd      T
# 645        tbd      E
# 657        tbd      E

# %% [markdown]
# But first I will change the "tbd" values to the average of the maximum user score rating(10), because at average the user did not explicitly decide whether it was a good or bad game.

# %%
df.loc[df['user_score'] == 'tbd', 'user_score'] = 5

# %%
df['user_score'] = df['user_score'].astype('float')

# %%
#missing values

# %% [markdown]
# Filling in missing values

# %%
df.isnull().sum()
# Out:
# name                  0
# platform              0
# year_of_release       0
# genre                 0
# na_sales              0
# eu_sales              0
# jp_sales              0
# other_sales           0
# critic_score       8578
# user_score            0
# rating             6766
# dtype: int64

# %% [markdown]
# `name` column has two missing values

# %%
df[df['name'].isnull()]
# Out:
# Empty DataFrame
# Columns: [name, platform, year_of_release, genre, na_sales, eu_sales, jp_sales, other_sales, critic_score, user_score, rating]
# Index: []

# %%
df[df['name'] == 'Game']
# Out:
#        name platform year_of_release genre  na_sales  eu_sales  jp_sales  \
# 659    Game      GEN      1993-01-01  Misc      1.78      0.53      0.00
# 14244  Game      GEN      1993-01-01  Misc      0.00      0.00      0.03
#
#        other_sales  critic_score  user_score rating
# 659           0.08           NaN        -1.0    NaN
# 14244         0.00           NaN        -1.0    NaN

# %% [markdown]
# Looking at the missing names, it seems that it is the same game recorded twice with separate records for `jp_sales`.
# I will fill in with an imaginary name.

# %%
#df.loc[df['name'].isnull(), 'name'] = 'Game'

# %%
#df.loc[df['name'] == 'Game']['jp_sales']
# Out:
# 659      0.00
# 14244    0.03
# Name: jp_sales, dtype: float64

# %% [markdown]
# `genre` has two missing values.
#
# I will fill in as Miscelleanous since it can not be determined exactly what genre they belong to.

# %%
df.loc[df['genre'].isnull(), 'genre'] = 'Misc'

# %% [markdown]
# `year_of_release` has 269 randomly missing values.
#
# The values could be missing because of lack of entry during data collection, or a program error during retrieval form the database.
#
# I will forward-fill in randomly using the fillna() method.

# %%
#df[df['year_of_release'].isnull()]
# Out:
#                                                name platform year_of_release  \
# 8547           Alone in the Dark: The New Nightmare       PS             NaT
# 183                                 Madden NFL 2004      PS2             NaT
# 3352                             The Golden Compass      Wii             NaT
# 16329                   Brothers in Arms: Furious 4     X360             NaT
# 13929                               Sega Rally 2006      PS2             NaT
# 10465        Disney's Chicken Little: Ace In Action      Wii             NaT
# 10486        Atsumare! Power Pro Kun no DS Koushien       DS             NaT
# 7353                                Ghostbusters II     2600             NaT
# 9293            Disney's Cinderella: Magical Dreams      GBA             NaT
# 8680                        Jurassic Park: The Game     X360             NaT
# 12568  Prinny: Can I Really Be The Hero? (US sales)      PSP             NaT
# 5800                                   Slot Machine     2600             NaT
# 4848                Harvest Moon: Save the Homeland      PS2             NaT
# 16448                                     Inversion       PC             NaT
# 4127                             Sonic the Hedgehog      PS3             NaT
# 9817                                   Street Hoops       GC             NaT
# 15119                    Legacy of Ys: Books I & II       DS             NaT
# 14252                                        Swords      Wii             NaT
# 15535                      Runaway: A Twist of Fate       DS             NaT
# 2132                   LEGO Harry Potter: Years 5-7     X360             NaT
# 4205                        Tiger Woods PGA Tour 07      Wii             NaT
# 15754                                  Virtua Quest      PS2             NaT
# 5443                                    Bejeweled 3       DS             NaT
# 10050                           Star Trek: Conquest      PS2             NaT
# 12003                                       Tornado       DS             NaT
# 16180             WRC: FIA World Rally Championship       PC             NaT
# 7367                            Robotech: Battlecry       XB             NaT
# 11565                               Rock Revolution      Wii             NaT
# 15953             PDC World Championship Darts 2008       DS             NaT
# 9485                              Street Fighter IV       PC             NaT
# 1840                                      Rock Band      PS2             NaT
# 8260                                    Backbreaker      PS3             NaT
# 8151                            Otomedius Excellent     X360             NaT
# 11433                      Zero: Tsukihami no Kamen      Wii             NaT
# 11016                     Samurai Shodown Anthology      PSP             NaT
# 12959                      Mountain Bike Adrenaline      PS2             NaT
# 12734                  Mobile Ops: The One Year War     X360             NaT
# 15704    Writing and Speaking Beautiful Japanese DS       DS             NaT
# 16157                  Aquaman: Battle for Atlantis       XB             NaT
# 11925                                 Port Royale 3      PS3             NaT
# 6199                                  Pac-Man Fever       GC             NaT
# 1142                                      Rock Band      PS3             NaT
# 9876                      Major League Baseball 2K6      PSP             NaT
# 6899               Danganronpa: Trigger Happy Havoc      PSP             NaT
# 2492                             MLB SlugFest 20-03      PS2             NaT
# 9830           Godzilla: Destroy All Monsters Melee       XB             NaT
# 6356                                Rock Revolution      PS3             NaT
# 6624                              College Hoops 2K6      PS2             NaT
# 4437                                 Super Breakout     2600             NaT
# 3081                   LEGO Harry Potter: Years 5-7       DS             NaT
#
#               genre  na_sales  eu_sales  jp_sales  other_sales  critic_score  \
# 8547      Adventure      0.09      0.06      0.00         0.01          77.0
# 183          Sports      4.26      0.26      0.01         0.71          94.0
# 3352         Action      0.26      0.28      0.00         0.07          35.0
# 16329       Shooter      0.01      0.00      0.00         0.00           NaN
# 13929        Racing      0.00      0.00      0.04         0.00           NaN
# 10465       Shooter      0.09      0.00      0.00         0.01          72.0
# 10486        Sports      0.00      0.00      0.10         0.00           NaN
# 7353         Action      0.20      0.01      0.00         0.00           NaN
# 9293       Platform      0.10      0.04      0.00         0.00          69.0
# 8680         Action      0.15      0.00      0.00         0.01          60.0
# 12568        Action      0.06      0.00      0.00         0.00           NaN
# 5800         Action      0.29      0.02      0.00         0.00           NaN
# 4848     Simulation      0.19      0.15      0.00         0.05          76.0
# 16448       Shooter      0.01      0.00      0.00         0.00          59.0
# 4127       Platform      0.00      0.48      0.00         0.00          43.0
# 9817         Sports      0.09      0.02      0.00         0.00          56.0
# 15119  Role-Playing      0.02      0.00      0.00         0.00           NaN
# 14252      Fighting      0.03      0.00      0.00         0.00           NaN
# 15535     Adventure      0.00      0.02      0.00         0.00          66.0
# 2132         Action      0.51      0.37      0.00         0.09          77.0
# 4205         Sports      0.43      0.00      0.00         0.04          71.0
# 15754  Role-Playing      0.01      0.01      0.00         0.00          53.0
# 5443         Puzzle      0.29      0.02      0.00         0.02          75.0
# 10050      Strategy      0.06      0.04      0.00         0.01          54.0
# 12003        Action      0.07      0.00      0.00         0.00          44.0
# 16180        Racing      0.00      0.01      0.00         0.00          65.0
# 7367        Shooter      0.16      0.05      0.00         0.01          74.0
# 11565          Misc      0.07      0.00      0.00         0.01          46.0
# 15953        Sports      0.01      0.00      0.00         0.00           NaN
# 9485       Fighting      0.07      0.05      0.00         0.02          91.0
# 1840           Misc      0.71      0.06      0.00         0.35          82.0
# 8260         Sports      0.16      0.00      0.00         0.01          58.0
# 8151        Shooter      0.13      0.00      0.04         0.01          48.0
# 11433        Action      0.00      0.00      0.08         0.00           NaN
# 11016      Fighting      0.08      0.00      0.00         0.01           NaN
# 12959        Sports      0.03      0.02      0.00         0.01           NaN
# 12734    Simulation      0.00      0.00      0.06         0.00           NaN
# 15704          Misc      0.00      0.00      0.02         0.00           NaN
# 16157        Action      0.01      0.00      0.00         0.00          26.0
# 11925    Simulation      0.06      0.00      0.00         0.01           NaN
# 6199           Misc      0.21      0.06      0.00         0.01          54.0
# 1142           Misc      0.99      0.41      0.00         0.22          92.0
# 9876         Sports      0.11      0.00      0.00         0.01          69.0
# 6899           Misc      0.00      0.00      0.24         0.00           NaN
# 2492         Sports      0.41      0.32      0.00         0.11          77.0
# 9830       Fighting      0.09      0.03      0.00         0.00          71.0
# 6356           Misc      0.25      0.00      0.00         0.02          42.0
# 6624         Sports      0.12      0.10      0.00         0.03          77.0
# 4437         Puzzle      0.41      0.03      0.00         0.00           NaN
# 3081         Action      0.34      0.25      0.00         0.07          69.0
#
#        user_score rating
# 8547          8.1      M
# 183           8.5      E
# 3352          6.8   E10+
# 16329         NaN      M
# 13929         NaN    NaN
# 10465         5.0   E10+
# 10486         NaN    NaN
# 7353          NaN    NaN
# 9293          5.0      E
# 8680          3.6      T
# 12568         NaN    NaN
# 5800          NaN    NaN
# 4848          8.8      E
# 16448         6.7      M
# 4127          4.1   E10+
# 9817          7.3      T
# 15119         NaN    NaN
# 14252         5.0      T
# 15535         NaN      T
# 2132          7.9   E10+
# 4205          6.9      E
# 15754         7.6      T
# 5443          5.0      E
# 10050         9.1      E
# 12003         5.0      E
# 16180         NaN     RP
# 7367          7.0      T
# 11565         5.0      T
# 15953         NaN    NaN
# 9485          8.0      T
# 1840          6.8      T
# 8260          7.0      E
# 8151          8.1      T
# 11433         NaN    NaN
# 11016         5.0      T
# 12959         5.0      E
# 12734         NaN    NaN
# 15704         NaN    NaN
# 16157         2.7      T
# 11925         8.9      T
# 6199          6.3      E
# 1142          8.4      T
# 9876          5.0      E
# 6899          NaN    NaN
# 2492          8.2      E
# 9830          6.8      T
# 6356          6.6      T
# 6624          7.3      E
# 4437          NaN    NaN
# 3081          5.0   E10+

# %%
df['year_of_release'].fillna(method='ffill', inplace=True)

# %% [markdown]
# `critic_score` and `user_score` have missing values that could be caused at the collection point whereby a user/critic did not provide this data.
#
# I will fill in the `user_score` with -1, to show that this data was not provided.

# %%
#df[df['critic_score'].isnull()]
# Out:
#                                 name platform year_of_release         genre  \
# 1                  Super Mario Bros.      NES      1985-01-01      Platform
# 4           Pokemon Red/Pokemon Blue       GB      1996-01-01  Role-Playing
# 5                             Tetris       GB      1989-01-01        Puzzle
# 9                          Duck Hunt      NES      1984-01-01       Shooter
# 10                        Nintendogs       DS      2005-01-01    Simulation
# ...                              ...      ...             ...           ...
# 16710  Samurai Warriors: Sanada Maru      PS3      2016-01-01        Action
# 16711               LMA Manager 2007     X360      2006-01-01        Sports
# 16712        Haitaka no Psychedelica      PSV      2016-01-01     Adventure
# 16713               Spirits & Spells      GBA      2003-01-01      Platform
# 16714            Winning Post 8 2016      PSV      2016-01-01    Simulation
#
#        na_sales  eu_sales  jp_sales  other_sales  critic_score  user_score  \
# 1         29.08      3.58      6.81         0.77           NaN         NaN
# 4         11.27      8.89     10.22         1.00           NaN         NaN
# 5         23.20      2.26      4.22         0.58           NaN         NaN
# 9         26.93      0.63      0.28         0.47           NaN         NaN
# 10         9.05     10.95      1.93         2.74           NaN         NaN
# ...         ...       ...       ...          ...           ...         ...
# 16710      0.00      0.00      0.01         0.00           NaN         NaN
# 16711      0.00      0.01      0.00         0.00           NaN         NaN
# 16712      0.00      0.00      0.01         0.00           NaN         NaN
# 16713      0.01      0.00      0.00         0.00           NaN         NaN
# 16714      0.00      0.00      0.01         0.00           NaN         NaN
#
#       rating
# 1        NaN
# 4        NaN
# 5        NaN
# 9        NaN
# 10       NaN
# ...      ...
# 16710    NaN
# 16711    NaN
# 16712    NaN
# 16713    NaN
# 16714    NaN
#
# [8578 rows x 11 columns]

# %%
df['user_score'].fillna(value=-1, inplace=True)

# %% [markdown]
# I will leave the missing values as is, in the `critic_score` because it does not affect my analysis.
#
# The `rating` column will also be left blank since this feature will be critical in my analysis.

# %%
df.duplicated().sum()
# Out:
# 0

# %% [markdown]
# #### Calculations:
#
# - Total sales for each game
#     - I will add the na, eu, jp and other sales columns

# %%
df['total_sales'] = df['eu_sales'] + df['na_sales'] +df['jp_sales'] +df['other_sales']

# %%
df.head(10)
# Out:
#                         name platform year_of_release         genre  na_sales  \
# 0                 Wii Sports      Wii      2006-01-01        Sports     41.36
# 1          Super Mario Bros.      NES      1985-01-01      Platform     29.08
# 2             Mario Kart Wii      Wii      2008-01-01        Racing     15.68
# 3          Wii Sports Resort      Wii      2009-01-01        Sports     15.61
# 4   Pokemon Red/Pokemon Blue       GB      1996-01-01  Role-Playing     11.27
# 5                     Tetris       GB      1989-01-01        Puzzle     23.20
# 6      New Super Mario Bros.       DS      2006-01-01      Platform     11.28
# 7                   Wii Play      Wii      2006-01-01          Misc     13.96
# 8  New Super Mario Bros. Wii      Wii      2009-01-01      Platform     14.44
# 9                  Duck Hunt      NES      1984-01-01       Shooter     26.93
#
#    eu_sales  jp_sales  other_sales  critic_score  user_score rating  \
# 0     28.96      3.77         8.45          76.0         8.0      E
# 1      3.58      6.81         0.77           NaN        -1.0    NaN
# 2     12.76      3.79         3.29          82.0         8.3      E
# 3     10.93      3.28         2.95          80.0         8.0      E
# 4      8.89     10.22         1.00           NaN        -1.0    NaN
# 5      2.26      4.22         0.58           NaN        -1.0    NaN
# 6      9.14      6.50         2.88          89.0         8.5      E
# 7      9.18      2.93         2.84          58.0         6.6      E
# 8      6.94      4.70         2.24          87.0         8.4      E
# 9      0.63      0.28         0.47           NaN        -1.0    NaN
#
#    total_sales
# 0        82.54
# 1        40.24
# 2        35.52
# 3        32.77
# 4        31.38
# 5        30.26
# 6        29.80
# 7        28.91
# 8        28.32
# 9        28.31

# %% [markdown]
# ### Data Analysis

# %%
df.pivot_table(index='year_of_release', values='name', aggfunc=['count'])
# Out:
#                 count
#                  name
# year_of_release
# 1980-01-01          9
# 1981-01-01         47
# 1982-01-01         37
# 1983-01-01         17
# 1984-01-01         14
# 1985-01-01         14
# 1986-01-01         21
# 1987-01-01         16
# 1988-01-01         15
# 1989-01-01         17
# 1990-01-01         16
# 1991-01-01         41
# 1992-01-01         44
# 1993-01-01         62
# 1994-01-01        121
# 1995-01-01        222
# 1996-01-01        268
# 1997-01-01        294
# 1998-01-01        386
# 1999-01-01        342
# 2000-01-01        358
# 2001-01-01        488
# 2002-01-01        849
# 2003-01-01        793
# 2004-01-01        770
# 2005-01-01        954
# 2006-01-01       1025
# 2007-01-01       1215
# 2008-01-01       1449
# 2009-01-01       1440
# 2010-01-01       1278
# 2011-01-01       1149
# 2012-01-01        666
# 2013-01-01        555
# 2014-01-01        590
# 2015-01-01        619
# 2016-01-01        514

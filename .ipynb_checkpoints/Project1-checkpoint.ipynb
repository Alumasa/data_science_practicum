# %%
import pandas as pd
import numpy as np

# %%
df =pd.read_csv('credit_scoring_eng.csv')
df.head()
# Out:
#    children  days_employed  dob_years            education  education_id  \
# 0         1   -8437.673028         42    bachelor's degree             0
# 1         1   -4024.803754         36  secondary education             1
# 2         0   -5623.422610         33  Secondary Education             1
# 3         3   -4124.747207         32  secondary education             1
# 4         0  340266.072047         53  secondary education             1
#
#        family_status  family_status_id gender income_type  debt  total_income  \
# 0            married                 0      F    employee     0     40620.102
# 1            married                 0      F    employee     0     17932.802
# 2            married                 0      M    employee     0     23341.752
# 3            married                 0      M    employee     0     42820.568
# 4  civil partnership                 1      F     retiree     0     25378.572
#
#                    purpose
# 0    purchase of the house
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 21525 entries, 0 to 21524
# Data columns (total 12 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   children          21525 non-null  int64
#  1   days_employed     19351 non-null  float64
#  2   dob_years         21525 non-null  int64
#  3   education         21525 non-null  object
#  4   education_id      21525 non-null  int64
#  5   family_status     21525 non-null  object
#  6   family_status_id  21525 non-null  int64
#  7   gender            21525 non-null  object
#  8   income_type       21525 non-null  object
#  9   debt              21525 non-null  int64
#  10  total_income      19351 non-null  float64
#  11  purpose           21525 non-null  object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 2.0+ MB

# %%
df.shape
# Out:
# (21525, 12)

# %%
df.sample(5)
# Out:
#        children  days_employed  dob_years            education  education_id  \
# 9204          0    -728.505315         39    Bachelor's Degree             0
# 2461          1   -4714.446461         60  secondary education             1
# 14455         0  371325.615879         55  secondary education             1
# 14576         0  387786.824509         57  secondary education             1
# 6505          1   -3129.804682         26    Bachelor's Degree             0
#
#            family_status  family_status_id gender income_type  debt  \
# 9204   civil partnership                 1      F    employee     0
# 2461   civil partnership                 1      M    employee     0
# 14455    widow / widower                 2      F     retiree     0
# 14576            married                 0      F     retiree     0
# 6505             married                 0      F    business     0
#
#        total_income                                   purpose
# ...

# %%
df.describe()
# Out:
#            children  days_employed     dob_years  education_id  \
# count  21525.000000   19351.000000  21525.000000  21525.000000
# mean       0.538908   63046.497661     43.293380      0.817236
# std        1.381587  140827.311974     12.574584      0.548138
# min       -1.000000  -18388.949901      0.000000      0.000000
# 25%        0.000000   -2747.423625     33.000000      1.000000
# 50%        0.000000   -1203.369529     42.000000      1.000000
# 75%        1.000000    -291.095954     53.000000      1.000000
# max       20.000000  401755.400475     75.000000      4.000000
#
#        family_status_id          debt   total_income
# count      21525.000000  21525.000000   19351.000000
# mean           0.972544      0.080883   26787.568355
# std            1.420324      0.272661   16475.450632
# min            0.000000      0.000000    3306.762000
# 25%            0.000000      0.000000   16488.504500
# 50%            0.000000      0.000000   23202.870000
# ...

# %%
df.columns
# Out:
# Index(['children', 'days_employed', 'dob_years', 'education', 'education_id',
#        'family_status', 'family_status_id', 'gender', 'income_type', 'debt',
#        'total_income', 'purpose'],
#       dtype='object')

# %%
df.drop(['days_employed'], axis=1, inplace=True)

# %%
df['education'].value_counts()
# Out:
# secondary education    13750
# bachelor's degree       4718
# SECONDARY EDUCATION      772
# Secondary Education      711
# some college             668
# BACHELOR'S DEGREE        274
# Bachelor's Degree        268
# primary education        250
# Some College              47
# SOME COLLEGE              29
# PRIMARY EDUCATION         17
# Primary Education         15
# graduate degree            4
# GRADUATE DEGREE            1
# Graduate Degree            1
# Name: education, dtype: int64

# %%
df['education'] = df['education'].str.lower()

# %%
df['family_status'].value_counts()
# Out:
# married              12380
# civil partnership     4177
# unmarried             2813
# divorced              1195
# widow / widower        960
# Name: family_status, dtype: int64

# %%
df.gender.value_counts()
df.reset_index(drop=True)
df.index
# Out:
# RangeIndex(start=0, stop=21525, step=1)

# %%
df['income_type'].value_counts()
#should a student be unemployed?
# Out:
# employee                       11119
# business                        5085
# retiree                         3856
# civil servant                   1459
# unemployed                         2
# entrepreneur                       2
# student                            1
# paternity / maternity leave        1
# Name: income_type, dtype: int64

# %%
df['debt'].value_counts()
# Out:
# 0    19784
# 1     1741
# Name: debt, dtype: int64

# %%
df.total_income.describe()
# Out:
# count     19351.000000
# mean      26787.568355
# std       16475.450632
# min        3306.762000
# 25%       16488.504500
# 50%       23202.870000
# 75%       32549.611000
# max      362496.645000
# Name: total_income, dtype: float64

# %%
df['dob_years'].unique()
# Out:
# array([42, 36, 33, 32, 53, 27, 43, 50, 35, 41, 40, 65, 54, 56, 26, 48, 24,
#        21, 57, 67, 28, 63, 62, 47, 34, 68, 25, 31, 30, 20, 49, 37, 45, 61,
#        64, 44, 52, 46, 23, 38, 39, 51,  0, 59, 29, 60, 55, 58, 71, 22, 73,
#        66, 69, 19, 72, 70, 74, 75], dtype=int64)

# %%
df['dob_years'].describe()
# Out:
# count    21525.000000
# mean        43.293380
# std         12.574584
# min          0.000000
# 25%         33.000000
# 50%         42.000000
# 75%         53.000000
# max         75.000000
# Name: dob_years, dtype: float64

# %%
df['family_status_id'].value_counts()
# Out:
# 0    12380
# 1     4177
# 4     2813
# 3     1195
# 2      960
# Name: family_status_id, dtype: int64

# %%
df['education_id'].value_counts()
# Out:
# 1    15233
# 0     5260
# 2      744
# 3      282
# 4        6
# Name: education_id, dtype: int64

# %%
#count number of nulls in every column
df.isnull().sum()
# Out:
# children               0
# dob_years              0
# education              0
# education_id           0
# family_status          0
# family_status_id       0
# gender                 0
# income_type            0
# debt                   0
# total_income        2174
# purpose                0
# dtype: int64

# %%
#fill nulls with 0 along columns
df.fillna(value=0, axis=1, inplace=True)

# %%
df.loc[df['dob_years'] == 0]
# Out:
#        children  dob_years            education  education_id family_status  \
# 99            0          0  secondary education             1       married
# 149           0          0  secondary education             1      divorced
# 270           3          0  secondary education             1       married
# 578           0          0  secondary education             1       married
# 1040          0          0    bachelor's degree             0      divorced
# ...         ...        ...                  ...           ...           ...
# 19829         0          0  secondary education             1       married
# 20462         0          0  secondary education             1       married
# 20577         0          0  secondary education             1     unmarried
# 21179         2          0    bachelor's degree             0       married
# 21313         0          0  secondary education             1     unmarried
#
# ...

# %%
df.loc[df['dob_years'] == 0, 'dob_years'] = df['dob_years'].median() 
df['dob_years'].describe()
# Out:
# count    21525.000000
# mean        43.490453
# std         12.218595
# min         19.000000
# 25%         34.000000
# 50%         42.000000
# 75%         53.000000
# max         75.000000
# Name: dob_years, dtype: float64

# %%
#Change data types:
#dob_years to integer
df['dob_years'] = df['dob_years'].astype(np.int64)

# %%
df['gender'] = df['gender'].astype('category')
df.gender.dtype
# Out:
# CategoricalDtype(categories=['F', 'M', 'XNA'], ordered=False)

# %%
df['education'] = df['education'].astype('category')

# %%
df.purpose.nunique()
# Out:
# 38

# %%
df['purpose'].value_counts()
# Out:
# wedding ceremony                            797
# having a wedding                            777
# to have a wedding                           774
# real estate transactions                    676
# buy commercial real estate                  664
# housing transactions                        653
# buying property for renting out             653
# transactions with commercial real estate    651
# purchase of the house                       647
# housing                                     647
# purchase of the house for my family         641
# construction of own property                635
# property                                    634
# transactions with my real estate            630
# building a real estate                      626
# buy real estate                             624
# purchase of my own house                    620
# building a property                         620
# housing renovation                          612
# buy residential real estate                 607
# ...

# %%
df['income_type'] = df['income_type'].astype('category')

# %%
df['family_status'] = df['family_status'].astype('category')

# %%
df.dtypes
# Out:
# children               int64
# dob_years              int64
# education           category
# education_id           int64
# family_status       category
# family_status_id       int64
# gender              category
# income_type         category
# debt                   int64
# total_income         float64
# purpose               object
# dtype: object

# %%
#Stemming and lemmatization
queries = list(df['purpose'])
print(type(queries))
queries[:10]
# Out:
# <class 'list'>
# ['purchase of the house',
#  'car purchase',
#  'purchase of the house',
#  'supplementary education',
#  'to have a wedding',
#  'purchase of the house',
#  'housing transactions',
#  'education',
#  'having a wedding',
#  'purchase of the house for my family']

# %%
counter = 0
for query in queries:
    if 'housing' in query:
        counter += 1
print(counter)
# Out:
# 1912

# %% [markdown]
# from nltk.stem import SnowballStemmer
# english_stemmer = SnowballStemmer('english')
# words = queries
# for word in words:
#     for each in word.split(' '):
#         #print('Source word -', word, ', after stemming -', english_stemmer.stem(each))

# %% [markdown]
# educ_counter = 0
# for query in queries:
#     for word in query.split(' '):
#         stemmed_word = english_stemmer.stem(word)
#         if stemmed_word == 'educ':
#             counter += 1
# print(counter)

# %% [markdown]
# property_counter = 0
# for query in queries:
#     for word in query.split(' '):
#         stemmed_word = english_stemmer.stem(word)
#         if stemmed_word == 'properti':
#             counter += 1
# print(counter)

# %% [markdown]
# for query in queries:
#     if 'educated' in query:
#         cat.append('Education')

# %%
from nltk.stem import SnowballStemmer
stemmer = SnowballStemmer('english')
words = ['wedding', 'estate', 'housing', 'house', 'property', 'car', 'education', 'university', 'educated']
stemmed_word = []
for word in words:
    stemmed_word.append(stemmer.stem(word))
print(stemmed_word)
# Out:
# ['wed', 'estat', 'hous', 'hous', 'properti', 'car', 'educ', 'univers', 'educ']

# %%
stemmed_word_uniq = ['wed', 'estat', 'hous', 'properti', 'car', 'educ', 'univers']
cat = []
for query in queries:
    for word in query.split(' '):
        for each in stemmed_word_uniq:
            if stemmer.stem(word) == each:
                cat.append(word)
print(len(cat))
# Out:
# 21978

# %%
cat[:20]
# Out:
# ['house',
#  'car',
#  'house',
#  'education',
#  'wedding',
#  'house',
#  'housing',
#  'education',
#  'wedding',
#  'house',
#  'estate',
#  'estate',
#  'wedding',
#  'car',
#  'estate',
#  'property',
#  'property',
#  'property',
#  'car',
#  'car']

# %%
purpose_id = []
real_estate = ['estate', 'housing', 'house', 'property']
education = ['education', 'university'] 
for i in cat:
    for each in real_estate:
        if i == each:
            purpose_id.append(each)
print(len(purpose_id))
# Out:
# 10840

# %%
for i in cat:
    for each in education:
        if i == each:
            purpose_id.append(each)
print(len(purpose_id))
# Out:
# 14903

# %%
for i in cat:
    if i == 'wedding':
        purpose_id.append('wedding')
print(len(purpose_id))
# Out:
# 17251

# %%
for i in cat:
    if i == 'car':
        purpose_id.append('car')
print(len(purpose_id))
# Out:
# 21088

# %%
cat2 = []
for query in df.purpose:
    for word in query.split(' '):
        for each in stemmed_word_uniq:
            if stemmer.stem(word) == each:
                cat2.append(word)

# %%
#df['purpose_name'] = pd.Series(cat2, dtype='object') #create an empty column
df.columns
# Out:
# Index(['children', 'dob_years', 'education', 'education_id', 'family_status',
#        'family_status_id', 'gender', 'income_type', 'debt', 'total_income',
#        'purpose'],
#       dtype='object')

# %%
def purpose_category(purpose):
    for query in df.purpose:
        for each in query.split(' '):
            stem = stemmer.stem(each)
            if stem == 'wed':
                return 'Wedding'
            if stem == 'estat':
                return 'Real Estate'
            if stem == 'hous':
                return 'Real Estate'
            if stem == 'properti':
                return 'Real Estate'
            if stem == 'car':
                return 'Car'
            if stem == 'educ':
                return 'Education'
            if stem == 'univers':
                return 'Education'
            else:
                return 'unknown stem'
 
df['purpose_category'] = df['purpose'].apply(purpose_category)    
 
 
df['purpose_category'].value_counts()
# Out:
# unknown stem    21525
# Name: purpose_category, dtype: int64

# %%
df.sample(50)
# Out:
#        children  dob_years            education  education_id  \
# 7154          0         44  secondary education             1
# 14886         0         56  secondary education             1
# 15762        20         41  secondary education             1
# 17309         0         43    bachelor's degree             0
# 4195          1         58  secondary education             1
# 7723          1         35    bachelor's degree             0
# 18187         0         67  secondary education             1
# 7583          0         40    bachelor's degree             0
# 21502         1         42  secondary education             1
# 5178          0         39    bachelor's degree             0
# 9186          0         48    bachelor's degree             0
# 12576         0         62  secondary education             1
# 15241         3         38    bachelor's degree             0
# 14623         0         56  secondary education             1
# ...

# %%
stemmed_word_uniq = ['wed', 'estat', 'hous', 'properti', 'car', 'educ', 'univers']
def purpose_cat2(purpose):
    for query in queries:
        for word in query.split(' '):
            for each in stemmed_word_uniq:
                if stemmer.stem(word) == each:
                    return each

df['purpose2'] = df['purpose'].apply(purpose_cat2)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-59-644a9b81635a> in <module>
#       7                     return each
#       8
# ----> 9 df['purpose2'] = df['purpose'].apply(purpose_cat2)
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\series.py in apply(self, func, convert_dtype, args, **kwds)
#    3846             else:
#    3847                 values = self.astype(object).values
# -> 3848                 mapped = lib.map_infer(values, f, convert=convert_dtype)
#    3849
#    3850         if len(mapped) and isinstance(mapped[0], Series):
#
# pandas\_libs\lib.pyx in pandas._libs.lib.map_infer()
#
# <ipython-input-59-644a9b81635a> in purpose_cat2(purpose)
#       1 stemmed_word_uniq = ['wed', 'estat', 'hous', 'properti', 'car', 'educ', 'univers']
#       2 def purpose_cat2(purpose):
# ----> 3     for query in queries.str:
# ...

# %%
df['purpose_cat2'].unique()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2645             try:
# -> 2646                 return self._engine.get_loc(key)
#    2647             except KeyError:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'purpose_cat2'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-56-a1ac5e624855> in <module>
# ----> 1 df['purpose_cat2'].unique()
# ...

# %%
#This works!!!
def purpose_cat3(purpose):
    stemmed = [stemmer.stem(word) for word in purpose.split(' ')]
    if 'wed' in stemmed:
        return 'wedding'
    if 'estat' in stemmed:
        return 'estate'
    if 'hous' in stemmed:
        return 'estate'
    if 'properti' in stemmed:
        return 'estate'
    if 'car' in stemmed:
        return 'car'
    if 'educ' in stemmed:
        return 'education'
    if 'univers' in stemmed:
        return 'education'
    else:
        return 'unknown'

# %%
df['purpose3'] = df['purpose'].apply(purpose_cat3)

# %%
df['purpose3'].value_counts()
# Out:
# estate       10840
# car           4315
# education     4022
# wedding       2348
# Name: purpose3, dtype: int64

# %%
df.purpose3.unique()
# Out:
# array(['estate', 'car', 'education', 'wedding'], dtype=object)

# %%
df.sample(50)
# Out:
#        children  dob_years            education  education_id  \
# 4078          0         63  secondary education             1
# 10228         1         38  secondary education             1
# 11890         0         39    bachelor's degree             0
# 9146          0         34    bachelor's degree             0
# 13966         0         57  secondary education             1
# 2869          0         38  secondary education             1
# 19539         1         62    bachelor's degree             0
# 5157          1         26  secondary education             1
# 20898         0         41  secondary education             1
# 3818          1         35    bachelor's degree             0
# 259           0         29    bachelor's degree             0
# 20672         0         36  secondary education             1
# 9416          0         40  secondary education             1
# 12552         2         38    primary education             3
# ...

# %%
df.children.value_counts()
# Out:
#  0     14149
#  1      4818
#  2      2055
#  3       330
#  20       76
# -1        47
#  4        41
#  5         9
# Name: children, dtype: int64

# %%
df['children'].describe()
# Out:
# count    21525.000000
# mean         0.538908
# std          1.381587
# min         -1.000000
# 25%          0.000000
# 50%          0.000000
# 75%          1.000000
# max         20.000000
# Name: children, dtype: float64
